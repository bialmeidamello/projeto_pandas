# %% [markdown]
# # Projeto prático Pandas
#
# O projeto será constituído de duas partes:
#
# 1. Exercícios de fixação das funcionalidades da biblioteca Pandas
# 2. Exercícios utilizando as bibliotecas para análise em Pandas

# %% [markdown]
# # Parte 1
# ## Revisão Pandas

# %% [markdown]
# ### Antes de tudo, execute o código a seguir e tire um tempo para observar os dados, a estrutura do código e o que ele faz

# %%
import pandas as pd

dados_mulheres_tecnologia = {
    'Nome': [
        'Ada Lovelace',
        'Grace Hopper',
        'Mary Jackson',
        'Nina da Hora',
        'Sonia Guimarães',
        'Hedy Lamarr',
        'Bárbara Flores Borum-Kren',
        'Mariéme Jamme',
        'Lynn Ann Conway'
    ],
    'Data Nascimento': [
        '10/12/1815',
        '09/12/1906',
        '09/04/1921',
        '1995',
        '26/06/1957',
        '09/11/1914',
        '1984',
        '1974',
        '02/01/1938'
    ],
   'Nacionalidade': [
        'Britânica',
        'Estadunidense',
        'Estadunidense',
        'Brasileira',
        'Brasileira',
        'Austríaca/Estadunidense',
        'Brasileira',
        'Senegalesa/Britânica',
        'Estadunidense'
    ],
    'Raça / Etnia': [
        'Branca',
        'Branca',
        'Negra',
        'Negra',
        'Negra',
        'Branca',
        'Indígena (Krenak)',
        'Negra',
        'Branca'
    ],
    'Gênero': [
        'Cisgênero',
        'Cisgênero',
        'Cisgênero',
        'Não-binário',
        'Cisgênero',
        'Cisgênero',
        'Cisgênero',
        'Cisgênero',
        'Transgênero'
    ],
    'Publicação': [
        'Notas sobre o Esquema de Babbage (Nota G)',
        'Understanding Computers',
        'Effects of Nose Angle and Mach Number on Transition on Cones at Supersonic Speeds (NACA TN 4388)',
        'MyNews Explica - Algoritmos',
        'Obtenção e transferencia de tecnologia de detectores de radiacao infravermelha atraves de crescimento epitaxial de ligas semicondutoras',
        'Patente para Sistema de Comunicação Secreta (Patente #2,292,387)',
        'Feminino e Sustentabilidade: A luta das mulheres não está separada da luta da natureza',
        'I Am The Code (Organização)',
        'Introduction to VLSI Systems'
    ],
    'Tipo de Publicação': [
        'Artigo',
        'Livro',
        'Relatório Científico',
        'Livro',
        'Trabalho Acadêmico',
        'Patente',
        'Trabalho Acadêmico',
        'Fundação/Iniciativa',
        'Livro'
    ],
    'Ano de Publicação': [
        1843,
        1984,
        1958,
        2023,
        2020,
        1942,
        2014,
        2017,
        1979
    ]
}

df_mulheres_tecnologia = pd.DataFrame(dados_mulheres_tecnologia)

print("DataFrame 1: Mulheres Pioneiras e Diversidade na Tecnologia e Ciência")
# print(df_mulheres_tecnologia)
df_mulheres_tecnologia
# Out:
# DataFrame 1: Mulheres Pioneiras e Diversidade na Tecnologia e Ciência
#                         Nome Data Nascimento            Nacionalidade  \
# 0               Ada Lovelace      10/12/1815                Britânica
# 1               Grace Hopper      09/12/1906            Estadunidense
# 2               Mary Jackson      09/04/1921            Estadunidense
# 3               Nina da Hora            1995               Brasileira
# 4            Sonia Guimarães      26/06/1957               Brasileira
# 5                Hedy Lamarr      09/11/1914  Austríaca/Estadunidense
# 6  Bárbara Flores Borum-Kren            1984               Brasileira
# 7              Mariéme Jamme            1974     Senegalesa/Britânica
# 8            Lynn Ann Conway      02/01/1938            Estadunidense
#
#         Raça / Etnia       Gênero  \
# 0             Branca    Cisgênero
# 1             Branca    Cisgênero
# 2              Negra    Cisgênero
# 3              Negra  Não-binário
# 4              Negra    Cisgênero
# 5             Branca    Cisgênero
# 6  Indígena (Krenak)    Cisgênero
# 7              Negra    Cisgênero
# 8             Branca  Transgênero
#
#                                           Publicação    Tipo de Publicação  \
# 0          Notas sobre o Esquema de Babbage (Nota G)                Artigo
# 1                            Understanding Computers                 Livro
# 2  Effects of Nose Angle and Mach Number on Trans...  Relatório Científico
# 3                        MyNews Explica - Algoritmos                 Livro
# 4  Obtenção e transferencia de tecnologia de dete...    Trabalho Acadêmico
# 5  Patente para Sistema de Comunicação Secreta (P...               Patente
# 6  Feminino e Sustentabilidade: A luta das mulher...    Trabalho Acadêmico
# 7                        I Am The Code (Organização)   Fundação/Iniciativa
# 8                       Introduction to VLSI Systems                 Livro
#
#    Ano de Publicação
# 0               1843
# 1               1984
# 2               1958
# 3               2023
# 4               2020
# 5               1942
# 6               2014
# 7               2017
# 8               1979

# %%
import pandas as pd

# %%
type(dados_mulheres_tecnologia)
# Out:
# dict

# %%
type(df_mulheres_tecnologia)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Agora responda as seguintes perguntas:
#
# 1. dados_mulheres_tecnologia é um exemplo de qual estrutura de dados/tipo? Resposta: Dicionário
#
# 2. df_mulheres_tecnologia é um exemplo de qual estrutura de dados?
# Resposta: Dataframe

# %% [markdown]
# ### Exercício 1
#
# Selecione as 3 primeiras linhas do dataframe

# %%
df_mulheres_tecnologia.head(3)
# Out:
#            Nome Data Nascimento  Nacionalidade Raça / Etnia     Gênero  \
# 0  Ada Lovelace      10/12/1815      Britânica       Branca  Cisgênero
# 1  Grace Hopper      09/12/1906  Estadunidense       Branca  Cisgênero
# 2  Mary Jackson      09/04/1921  Estadunidense        Negra  Cisgênero
#
#                                           Publicação    Tipo de Publicação  \
# 0          Notas sobre o Esquema de Babbage (Nota G)                Artigo
# 1                            Understanding Computers                 Livro
# 2  Effects of Nose Angle and Mach Number on Trans...  Relatório Científico
#
#    Ano de Publicação
# 0               1843
# 1               1984
# 2               1958

# %% [markdown]
# ### Exercício 2
# Slecione as 3 últimas linhas do dataframe

# %%
df_mulheres_tecnologia.tail(3)
# Out:
#                         Nome Data Nascimento         Nacionalidade  \
# 6  Bárbara Flores Borum-Kren            1984            Brasileira
# 7              Mariéme Jamme            1974  Senegalesa/Britânica
# 8            Lynn Ann Conway      02/01/1938         Estadunidense
#
#         Raça / Etnia       Gênero  \
# 6  Indígena (Krenak)    Cisgênero
# 7              Negra    Cisgênero
# 8             Branca  Transgênero
#
#                                           Publicação   Tipo de Publicação  \
# 6  Feminino e Sustentabilidade: A luta das mulher...   Trabalho Acadêmico
# 7                        I Am The Code (Organização)  Fundação/Iniciativa
# 8                       Introduction to VLSI Systems                Livro
#
#    Ano de Publicação
# 6               2014
# 7               2017
# 8               1979

# %% [markdown]
# ### Exercício 3
#
# Conte quantas linhas tem no dataframe

# %%
df_mulheres_tecnologia.shape[0]
# Out:
# 9

# %% [markdown]
# ### Exercício 4
# Selecione apenas as seguintes colunas do dataframe
# - Nome
# - Publicação
# - Tipo de Publicação
# - Ano de Publicação

# %%
df_mulheres_tecnologia[['Nome', 'Publicação', 'Tipo de Publicação', 'Ano de Publicação']]
# Out:
#                         Nome  \
# 0               Ada Lovelace
# 1               Grace Hopper
# 2               Mary Jackson
# 3               Nina da Hora
# 4            Sonia Guimarães
# 5                Hedy Lamarr
# 6  Bárbara Flores Borum-Kren
# 7              Mariéme Jamme
# 8            Lynn Ann Conway
#
#                                           Publicação    Tipo de Publicação  \
# 0          Notas sobre o Esquema de Babbage (Nota G)                Artigo
# 1                            Understanding Computers                 Livro
# 2  Effects of Nose Angle and Mach Number on Trans...  Relatório Científico
# 3                        MyNews Explica - Algoritmos                 Livro
# 4  Obtenção e transferencia de tecnologia de dete...    Trabalho Acadêmico
# 5  Patente para Sistema de Comunicação Secreta (P...               Patente
# 6  Feminino e Sustentabilidade: A luta das mulher...    Trabalho Acadêmico
# 7                        I Am The Code (Organização)   Fundação/Iniciativa
# 8                       Introduction to VLSI Systems                 Livro
#
#    Ano de Publicação
# 0               1843
# 1               1984
# 2               1958
# 3               2023
# 4               2020
# 5               1942
# 6               2014
# 7               2017
# 8               1979

# %% [markdown]
# ### Exercício 5
#
# Ordene por Ano de Publicação

# %%
df_mulheres_tecnologia.sort_values(by ='Ano de Publicação')
# Out:
#                         Nome Data Nascimento            Nacionalidade  \
# 0               Ada Lovelace      10/12/1815                Britânica
# 5                Hedy Lamarr      09/11/1914  Austríaca/Estadunidense
# 2               Mary Jackson      09/04/1921            Estadunidense
# 8            Lynn Ann Conway      02/01/1938            Estadunidense
# 1               Grace Hopper      09/12/1906            Estadunidense
# 6  Bárbara Flores Borum-Kren            1984               Brasileira
# 7              Mariéme Jamme            1974     Senegalesa/Britânica
# 4            Sonia Guimarães      26/06/1957               Brasileira
# 3               Nina da Hora            1995               Brasileira
#
#         Raça / Etnia       Gênero  \
# 0             Branca    Cisgênero
# 5             Branca    Cisgênero
# 2              Negra    Cisgênero
# 8             Branca  Transgênero
# 1             Branca    Cisgênero
# 6  Indígena (Krenak)    Cisgênero
# 7              Negra    Cisgênero
# 4              Negra    Cisgênero
# 3              Negra  Não-binário
#
#                                           Publicação    Tipo de Publicação  \
# 0          Notas sobre o Esquema de Babbage (Nota G)                Artigo
# 5  Patente para Sistema de Comunicação Secreta (P...               Patente
# 2  Effects of Nose Angle and Mach Number on Trans...  Relatório Científico
# 8                       Introduction to VLSI Systems                 Livro
# 1                            Understanding Computers                 Livro
# 6  Feminino e Sustentabilidade: A luta das mulher...    Trabalho Acadêmico
# 7                        I Am The Code (Organização)   Fundação/Iniciativa
# 4  Obtenção e transferencia de tecnologia de dete...    Trabalho Acadêmico
# 3                        MyNews Explica - Algoritmos                 Livro
#
#    Ano de Publicação
# 0               1843
# 5               1942
# 2               1958
# 8               1979
# 1               1984
# 6               2014
# 7               2017
# 4               2020
# 3               2023

# %%
import re

def extract_year(date_str):
  """
  Extracts a four-digit year from a string.
  Returns the year as an integer if found, otherwise returns None.
  """
  if isinstance(date_str, str):
    match = re.search(r'\b\d{4}\b', date_str)
    if match:
      return int(match.group(0))
  return None

# Apply the function to the original 'Data Nascimento' list to extract years
extracted_years = [extract_year(date_str) for date_str in dados_mulheres_tecnologia['Data Nascimento']]

# Fill the missing values in 'Ano Nascimento' with the extracted years
# We need to convert the extracted_years list to a pandas Series to use fillna effectively
df_mulheres_tecnologia['Ano Nascimento'] = df_mulheres_tecnologia['Ano Nascimento'].fillna(pd.Series(extracted_years)).astype('Int64')

# Display the updated 'Ano Nascimento' column
print(df_mulheres_tecnologia['Ano Nascimento'])
# Out:
# 0    1815
# 1    1906
# 2    1921
# 3    1995
# 4    1957
# 5    1914
# 6    1984
# 7    1974
# 8    1938
# Name: Ano Nascimento, dtype: Int64

# %% [markdown]
# ### Exercício 6
# Gere um gráfico demonstrando os tipos de publicação

# %%
import matplotlib.pyplot as plt

df_mulheres_tecnologia['Tipo de Publicação'].value_counts().plot(
    kind='bar',
    figsize=(8, 5),
    title='Distribuição dos Tipos de Publicação entre Mulheres na Tecnologia',
    xlabel='Tipo de Publicação',
    ylabel='Quantidade'
)

plt.show()

# %% [markdown]
# ### Exercício 7
#
# #### 7.1
# - Defina uma pergunta de análise que possa ser respondida a partir dos dados existentes ou complementares.
# - Adicione uma nova coluna ao DataFrame *df_mulheres_tecnologia* cujos valores permitam responder à sua pergunta (Passo 1).
#
# #### 7.2
# - Crie um gráfico utilizando a nova coluna (e outras, se necessário) para visualizar a resposta à sua pergunta.
# - Descreva o que o gráfico revela sobre as mulheres na tecnologia e ciência.

# %%
#Qual a relação entre raça/etinia e o ano de publicação da primeira obra das autoras?

# Criar uma nova coluna com o ano de nascimento
import re

def extract_year(date_str):

  if isinstance(date_str, str):
    match = re.search(r'\b\d{4}\b', date_str)
    if match:
      return int(match.group(0))
  return None

extracted_years = [extract_year(date_str) for date_str in dados_mulheres_tecnologia['Data Nascimento']]

df_mulheres_tecnologia['Ano Nascimento'] = df_mulheres_tecnologia['Ano Nascimento'].fillna(pd.Series(extracted_years)).astype('Int64')

df_mulheres_tecnologia['Ano Nascimento']

#Calcular ano da autora no ano de publicação
df_mulheres_tecnologia['Idade na Publicação'] = (
    df_mulheres_tecnologia['Ano de Publicação'] - df_mulheres_tecnologia['Ano Nascimento']
)

df_mulheres_tecnologia['Idade na Publicação']
# Out:
# 0    28
# 1    78
# 2    37
# 3    28
# 4    63
# 5    28
# 6    30
# 7    43
# 8    41
# Name: Idade na Publicação, dtype: Int64

# %%
import matplotlib.pyplot as plt

df_mulheres_tecnologia['Raça / Etnia'].value_counts().plot(
    kind='bar',
    figsize=(8, 5),
    title='Distribuição dos Tipos de Publicação por Raça/Etnia',
    xlabel='Raça / Etnia',
    ylabel='Número de Mulheres'
)

plt.show()

# %%
import matplotlib.pyplot as plt

df_mulheres_tecnologia['Idade na Publicação'].value_counts().plot(
    kind='bar',
    figsize=(8, 5),
    title='Distribuição dos Tipos de Publicação por Raça/Etnia',
    xlabel='Idade na Publicação',
    ylabel='Número de Mulheres'
)

plt.show()

# %%
tabela = pd.crosstab(df_mulheres_tecnologia["Idade na Publicação"], df_mulheres_tecnologia["Raça / Etnia"])

tabela.plot(
    kind= "bar",
    figsize= (8, 5),
    title= "Plublicações por raça/etinia e idade",
    xlabel= "Idade na publicação",
    ylabel= "Quantidade de mulheres",

)

plt.show()

#O gráfico revela que mulheres negras tendem a ter seus livros publicados depois de mais velhas, se conparadas com as autoras brancas.
#Podemos supor que a diferença se dá devido a disparidade entre acesso à educação entre mulheres brancas e negras.

# %% [markdown]
# # Parte 2
#
# ## Análise de dados com Python e Pandas

# %% [markdown]
# ### Exercício
# Vamos fazer juntas!
#
# O que vamos praticar?
# - Importar arquivo csv com o pandas
# - Importar arquivo no formato json
# - Fazer análise exploratória
# - Manipular colunas com pandas
# - Montar gráficos com pandas
#
# #### Fazer upload das bases de dados
# Vamos trabalhar com a base de dados da **Câmara dos deputados referente à legislatura 57**, a mesma utilizada no módulo de Planilhas. Porém dessa vez vamos combinar duas bases (uma em csv e outra em formato json)
#
# 1. Baixe o arquivo [deputados_legislatura_57_base_tratada.csv](https://drive.google.com/file/d/1GZO-zaf7ofbnth8BkwnJptVAtZDwuUW0/view?usp=drive_link)
# 1. Baixe o arquivo [deputados_legislatura_57.json](https://drive.google.com/file/d/1GHx1NiMCX-WWHPkzesFNmPvcgSLZl-0W/view?usp=drive_link)
# 2. No menu lateral esquerdo aqui do Colab, clique no ícone de arquivos
# 3. Selecione a opção de fazer upload e selecione os arquivos você baixou anteriormente
#
# Observação: Para encontrar o caminho completo da base de dados importada:
# - Clique com o botão direito sobre o arquivo importado
# - Selecione "Copiar caminho"
#
#
# #### Importar a biblioteca pandas executando o código a seguir

# %%
import pandas as pd

# %% [markdown]
# #### Lidando com dados em csv
#
# Execute o bloco de código a seguir para transformar os dados csv em Data Frame

# %%
# Definindo o caminho para buscar a base de dados
base_dados_deputados_csv = '/content/deputados_legislatura_57_base_tratada.csv'

# Transformando a base de dados de csv para o formato Data Frame
df_deputados_csv = pd.read_csv(base_dados_deputados_csv)

#selecionar apenas algumas colunas
colunas_csv = ['Nome', 'Estado', 'Sigla Gênero', 'Gênero', 'Data de nascimento', 'Idade', 'Primeira legislatura']
df_deputados_csv = df_deputados_csv[colunas_csv]

# Exibir as colunas do dataframe
print(df_deputados_csv.columns)

# Exibir as quantidade de linhas
df_deputados_csv.value_counts()
# Out:
# Index(['Nome', 'Estado', 'Sigla Gênero', 'Gênero', 'Data de nascimento',
#        'Idade', 'Primeira legislatura'],
#       dtype='object')
# Nome            Estado  Sigla Gênero  Gênero     Data de nascimento  Idade  Primeira legislatura
# Átila Lira      PI      M             Masculino  01/04/1980          45     True                    1
# AJ Albuquerque  CE      M             Masculino  26/09/1983          42     True                    1
# Abilio Brunini  MT      M             Masculino  31/01/1984          41     True                    1
# Acácio Favacho  AP      M             Masculino  28/09/1983          42     True                    1
# Adail Filho     AM      M             Masculino  16/02/1992          33     True                    1
#                                                                                                    ..
# Alceu Moreira   RS      M             Masculino  04/06/1954          71     True                    1
# Albuquerque     CE      M             Masculino  25/01/1974          51     True                    1
# Alberto Mourão  SP      M             Masculino  26/04/1954          71     True                    1
# Alberto Fraga   SE      M             Masculino  02/06/1956          69     True                    1
# Airton Faleiro  RS      M             Masculino  16/03/1959          66     True                    1
# Name: count, Length: 620, dtype: int64

# %%
df_deputados_csv
# Out:
#                 Nome Estado Sigla Gênero     Gênero Data de nascimento  Idade  \
# 0     Abilio Brunini     MT            M  Masculino         31/01/1984     41
# 1     Acácio Favacho     AP            M  Masculino         28/09/1983     42
# 2        Adail Filho     AM            M  Masculino         16/02/1992     33
# 3    Adilson Barroso     MG            M  Masculino         14/06/1964     61
# 4       Adolfo Viana     BA            M  Masculino         02/02/1981     44
# ..               ...    ...          ...        ...                ...    ...
# 615        Zé Trovão     SP            M  Masculino         22/07/1988     37
# 616         Zé Vitor     MG            M  Masculino         01/11/1984     40
# 617      Zeca Dirceu     PR            M  Masculino         21/06/1978     47
# 618  Zezinho Barbary     AC            M  Masculino         28/05/1966     59
# 619            Zucco     RS            M  Masculino         09/03/1974     51
#
#      Primeira legislatura
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True
# ..                    ...
# 615                  True
# 616                  True
# 617                  True
# 618                  True
# 619                  True
#
# [620 rows x 7 columns]

# %% [markdown]
# #### Lidando com dados em json
#
# Execute o bloco de código a seguir para transformar os dados json em Data Frame

# %%
import json

# Definindo o caminho para buscar a base de dados
base_dados_deputados_json = '/content/deputados_legislatura_57.json'

# Transformando a base de dados de json para o formato Data Frame
df_deputados_json = pd.read_json(base_dados_deputados_json)

#selecionar apenas algumas colunas
colunas_json = ['id', 'nome', 'siglaPartido', 'email']
df_deputados_json = df_deputados_json[colunas_json]

# Exibir as colunas do dataframe
print(df_deputados_json.columns)

# Exibir as quantidade de linhas
print(df_deputados_json.value_counts)

# Imprime os as colunas do dataframe
print(df_deputados_json.columns)
print(df_deputados_json.value_counts)
# Out:
# Index(['id', 'nome', 'siglaPartido', 'email'], dtype='object')
# <bound method DataFrame.value_counts of          id             nome  siglaPartido                             email
# 0    220593   Abilio Brunini            PL                              None
# 1    204379   Acácio Favacho           MDB   dep.acaciofavacho@camara.leg.br
# 2    220714      Adail Filho  REPUBLICANOS      dep.adailfilho@camara.leg.br
# 3    221328  Adilson Barroso            PL  dep.adilsonbarroso@camara.leg.br
# 4    204560     Adolfo Viana          PSDB     dep.adolfoviana@camara.leg.br
# ..      ...              ...           ...                               ...
# 689  204517         Zé Vitor            PL         dep.zevitor@camara.leg.br
# 690  160592      Zeca Dirceu            PT      dep.zecadirceu@camara.leg.br
# 691  220592  Zezinho Barbary            PP  dep.zezinhobarbary@camara.leg.br
# 692  220552            Zucco  REPUBLICANOS           dep.zucco@camara.leg.br
# 693  220552            Zucco            PL           dep.zucco@camara.leg.br
#
# [694 rows x 4 columns]>
# Index(['id', 'nome', 'siglaPartido', 'email'], dtype='object')
# <bound method DataFrame.value_counts of          id             nome  siglaPartido                             email
# 0    220593   Abilio Brunini            PL                              None
# 1    204379   Acácio Favacho           MDB   dep.acaciofavacho@camara.leg.br
# 2    220714      Adail Filho  REPUBLICANOS      dep.adailfilho@camara.leg.br
# 3    221328  Adilson Barroso            PL  dep.adilsonbarroso@camara.leg.br
# 4    204560     Adolfo Viana          PSDB     dep.adolfoviana@camara.leg.br
# ..      ...              ...           ...                               ...
# 689  204517         Zé Vitor            PL         dep.zevitor@camara.leg.br
# 690  160592      Zeca Dirceu            PT      dep.zecadirceu@camara.leg.br
# 691  220592  Zezinho Barbary            PP  dep.zezinhobarbary@camara.leg.br
# 692  220552            Zucco  REPUBLICANOS           dep.zucco@camara.leg.br
# 693  220552            Zucco            PL           dep.zucco@camara.leg.br
#
# [694 rows x 4 columns]>

# %% [markdown]
# #### Juntar bases de dados em uma só
#
# Vamos utilizar o conceito de [joins (ou junção)](https://https://www.alura.com.br/artigos/join-e-seus-tipos?srsltid=AfmBOorqiWzXLMyZKkskHWph08lQWzlGAOAJJ-DQR-cC4DF46cQ_VnA1 ) para mesclar as duas bases em uma só a partir da coluna "nome"

# %%
# Juntar as duas bases num inner join usando as colunas de nome
df_deputados_final = pd.merge(
    df_deputados_json,
    df_deputados_csv,
    left_on='nome',
    right_on='Nome',
    how='inner'
)

# Remover a coluna duplicada Nome
df_deputados_final = df_deputados_final.drop(columns=['Nome'])

print(df_deputados_final.head(3))
# Out:
#        id            nome  siglaPartido                            email  \
# 0  220593  Abilio Brunini            PL                             None
# 1  204379  Acácio Favacho           MDB  dep.acaciofavacho@camara.leg.br
# 2  220714     Adail Filho  REPUBLICANOS     dep.adailfilho@camara.leg.br
#
#   Estado Sigla Gênero     Gênero Data de nascimento  Idade  \
# 0     MT            M  Masculino         31/01/1984     41
# 1     AP            M  Masculino         28/09/1983     42
# 2     AM            M  Masculino         16/02/1992     33
#
#    Primeira legislatura
# 0                  True
# 1                  True
# 2                  True

# %% [markdown]
# #### Análise
#
# Agora é com você!
#
# 1. Qual a quantidade de parlamentares por estado e gênero?
# 2. Qual a média de idade por gênero de parlamentares?
# 3. Qual a proporção de reeleição e primeira legislatura  por gênero?
# 4. Quais partidos têm a maior quantidade de deputadas mulheres e qual é a proporção de mulheres em relação aos homens em cada partido?
# 5. Faça um inner join e conte quantos nomes ficaram de fora do CSV e do JSON. → Dica: compare os tamanhos antes e depois do merge.
#
# Extra (opcional):
#
# Faça uma pergunta extra  e uma visualização com base na nova coluna adicionada *siglaPartido*

# %% [markdown]
# 1. Qual a quantidade de parlamentares por estado e gênero?

# %%
qtd_por_estado_genero = df_deputados_final.groupby(['Estado', 'Gênero']).size()
qtd_por_estado_genero
# Out:
# Estado  Gênero
# AC      Feminino      3
#         Masculino     6
# AL      Masculino    10
# AM      Masculino     8
# AP      Feminino      5
#         Masculino     4
# BA      Feminino      5
#         Masculino    42
# CE      Feminino     10
#         Masculino    32
# DF      Masculino     6
# ES      Feminino      3
#         Masculino     7
# GO      Feminino      3
#         Masculino    19
# MA      Feminino      7
#         Masculino    23
# MG      Feminino     15
#         Masculino    71
# MS      Feminino      1
#         Masculino     5
# MT      Feminino      3
#         Masculino     5
# PA      Feminino      6
#         Masculino    15
# PB      Feminino      2
#         Masculino    19
# PE      Feminino      3
#         Masculino    28
# PI      Masculino    13
# PR      Feminino      9
#         Masculino    37
# RJ      Feminino     12
#         Masculino    59
# RN      Feminino      1
#         Masculino     6
# RO      Feminino      2
#         Masculino     2
# RR      Masculino     4
# RS      Feminino      7
#         Masculino    33
# SC      Feminino      5
#         Masculino    16
# SE      Feminino      2
#         Masculino     9
# SP      Feminino     18
#         Masculino    72
# TO      Feminino      1
#         Masculino     3
# dtype: int64

# %% [markdown]
# 2. Qual a média de idade por gênero de parlamentares?

# %%
media_idade_genero = df_deputados_final.groupby('Gênero')['Idade'].mean().round(1)
df_deputados_final.groupby('Gênero')['Idade'].mean()

media_idade_genero
# Out:
# Gênero
# Feminino     49.6
# Masculino    53.2
# Name: Idade, dtype: float64

# %% [markdown]
# 3. Qual a proporção de reeleição e primeira legislatura por gênero?

# %%
# Contagem cruzada
proporcao_reeleicao = pd.crosstab(df_deputados_final['Gênero'], df_deputados_final['Primeira legislatura'], normalize='index') * 100

pd.crosstab(df_deputados_final['Gênero'], df_deputados_final['Primeira legislatura'], normalize='index')

print(proporcao_reeleicao.round(1))
# Out:
# Primeira legislatura  False  True
# Gênero
# Feminino                0.8   99.2
# Masculino               3.1   96.9

# %% [markdown]
# 4. Quais partidos têm a maior quantidade de deputadas mulheres e qual é a proporção de mulheres em relação aos homens em cada partido?

# %%
# Filtrar apenas mulheres
df_mulheres = df_deputados_final[df_deputados_final['Gênero'] == 'Feminino']

# Contar mulheres por partido
mulheres_partido = df_mulheres['siglaPartido'].value_counts().head(10)

# %%
# Contar quantidade de mulheres e homens por partido
genero_partido = df_deputados_final.groupby(['siglaPartido', 'Gênero']).size().unstack(fill_value=0)

# Calcular o total de deputados por partido
genero_partido['Total'] = genero_partido.sum(axis=1)

# Calcular a porcentagem de mulheres em relação ao total
genero_partido['% Mulheres'] = (genero_partido['Feminino'] / genero_partido['Total']) * 100

# Ordenar pelos partidos com mais mulheres
resultado = genero_partido.sort_values(by='Feminino', ascending=False)

# Mostrar as 10 primeiras linhas
resultado.head(10)
# Out:
# Gênero        Feminino  Masculino  Total  % Mulheres
# siglaPartido
# PT                  21         57     78   26.923077
# PL                  20         99    119   16.806723
# MDB                 11         42     53   20.754717
# UNIÃO               11         61     72   15.277778
# REPUBLICANOS         9         51     60   15.000000
# PSOL                 8          7     15   53.333333
# PP                   7         57     64   10.937500
# PCdoB                5          4      9   55.555556
# PODE                 5         21     26   19.230769
# PDT                  5         17     22   22.727273

# %%
# Formatar a coluna de porcentagem com duas casas decimais e o símbolo %
resultado['% Mulheres'] = resultado['% Mulheres'].apply(lambda x: f'{x:.2f}%')

# Exibir novamente
resultado.head(10)
# Out:
# Gênero        Feminino  Masculino  Total % Mulheres
# siglaPartido
# PT                  21         57     78     26.92%
# PL                  20         99    119     16.81%
# MDB                 11         42     53     20.75%
# UNIÃO               11         61     72     15.28%
# REPUBLICANOS         9         51     60     15.00%
# PSOL                 8          7     15     53.33%
# PP                   7         57     64     10.94%
# PCdoB                5          4      9     55.56%
# PODE                 5         21     26     19.23%
# PDT                  5         17     22     22.73%

# %% [markdown]
# 5. Faça um inner join e conte quantos nomes ficaram de fora do CSV e do JSON. → Dica: compare os tamanhos antes e depois do merge.

# %%
# Imprimir o número de linhas nos dataframes originais
print(f"Número de linhas no dataframe CSV original: {df_deputados_csv.shape[0]}")
print(f"Número de linhas no dataframe JSON original: {df_deputados_json.shape[0]}")


# Juntar as duas bases num inner join usando as colunas de nome
df_deputados_final = pd.merge(
    df_deputados_json,
    df_deputados_csv,
    left_on='nome',
    right_on='Nome',
    how='inner'
)

# Remover a coluna duplicada Nome
df_deputados_final = df_deputados_final.drop(columns=['Nome'])

# Imprimir o número de linhas no dataframe final após o inner join
print(f"Número de linhas no dataframe final após o inner join: {df_deputados_final.shape[0]}")

# Calcular quantos nomes ficaram de fora

nomes_fora = (df_deputados_csv.shape[0] + df_deputados_json.shape[0]) - df_deputados_final.shape[0]
print(f"Número total de linhas 'perdidas' ou que não tiveram correspondência no inner join: {nomes_fora}")
# Out:
# Número de linhas no dataframe CSV original: 620
# Número de linhas no dataframe JSON original: 694
# Número de linhas no dataframe final após o inner join: 677
# Número total de linhas 'perdidas' ou que não tiveram correspondência no inner join: 637
